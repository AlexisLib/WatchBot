# %%
import numpy as np
import pandas as pd
import math
from math import *
import boto3
import io
import os
import datetime
from datetime import date, timedelta
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
def IMC(dataframe,id_user):
        
    columns = {'id_user': dataframe['iduser'],'Height': dataframe['height'],'Weight': dataframe['weight']}
    df_IMC = pd.DataFrame(columns)
    df_user = df_IMC[(df_IMC['id_user'] == id_user)]
    line_imc = df_IMC.tail(1)
    h= line_imc['Height'].values
    w= line_imc['Weight'].values
    taille = h[0]
    poids = w[0]
    imc_formula = poids / (taille*0.01)**2
    if (imc_formula < 18.5):
        return "Vous êtes en Insuffisance pondérale (maigreur)";
    elif (imc_formula > 18.5 or imc_formula < 25):
        return "Vous êtes en corpulence normale";
    elif (imc_formula > 25 or imc_formula < 30):
        return "Vous êtes en surpoids";
    elif (imc_formula > 30 or imc_formula < 35):
        return "Vous êtes en Obésité modérée";
    elif (imc_formula > 35 or imc_formula < 40):
        return "Vous êtes en Obésité sévère";
    elif (imc_formula < 40):
        return "Vous êtes en Obésité morbide ou massive";

# %%
def evolution_number_IMC(dataframe,id_user):
    
    now = datetime.datetime.now()
    columns = {'id_user': dataframe['iduser'],'Height': dataframe['height'],'Weight': dataframe['weight'],"Date": dataframe['date']}
    df_IMC = pd.DataFrame(columns)
    df_user = df_IMC[(df_IMC['id_user'] == id_user)]
    imcs= []
    for i in df_user.itertuples():
        imc_formula = i.Weight / (i.Height*0.01)**2
        imcs.append(imc_formula)
    
    columns = {'id_user': dataframe['iduser'],'Height': dataframe['height'],'Weight': dataframe['weight'],"Date": dataframe['date'],"IMC":imcs}
    df_IMC_2 = pd.DataFrame(columns)
    df_group = df_IMC_2.groupby(df_IMC_2["Date"]).agg("max")
    columns_values = pd.to_numeric(df_group["IMC"].values)
    dates = df_group.index

    fig = plt.figure()
    x=np.array(dates)
    y=np.array(columns_values)
    plt.axhline(y=18.5,color="grey",linestyle='--',label = "maigreur")
    plt.axhline(y=25 ,color="green",linestyle='--',label = "normale")
    plt.axhline(y=30,color="yellow",linestyle='--',label = "surpoids")
    plt.axhline(y=35 ,color="orange",linestyle='--',label = "obèse modèrée")
    plt.axhline(y=40,color="red",linestyle='--',label = "obèse massive")

    plt.plot(x,y,marker="o")
    plt.legend()
    
    plt.gcf().set_size_inches(len(dates)+5,9)
    img_title = "graph_evolution_number_IMC"+"_"+str(now.strftime("%d-%m-%Y_%H%M%S"))+".png"
    fig.suptitle(img_title, fontsize=16)
    path = "Graphes/user_"+str(id_user)+"/"+img_title
    fig.savefig(path)
    plt.close()

    return str("IMG:"+ path)

# %%
def evolution_average_IMC(dataframe,id_user):
    
    now = datetime.datetime.now()
    columns = {'id_user': dataframe['iduser'],'Height': dataframe['height'],'Weight': dataframe['weight'],"Date": dataframe['date']}
    df_IMC = pd.DataFrame(columns)
    df_user = df_IMC[(df_IMC['id_user'] == id_user)]
    imcs= []
    for i in df_user.itertuples():
        imc_formula = i.Weight / (i.Height*0.01)**2
        imcs.append(imc_formula)
    
    columns = {'id_user': dataframe['iduser'],'Height': dataframe['height'],'Weight': dataframe['weight'],"Date": dataframe['date'],"IMC":imcs}
    df_IMC_2 = pd.DataFrame(columns)
    df_group = df_IMC_2.groupby(df_IMC_2["Date"]).mean()
    columns_values = pd.to_numeric(df_group["IMC"].values)
    dates = df_group.index

    fig = plt.figure()
    x=np.array(dates)
    y=np.array(columns_values)

    plt.axhline(y=18.5,color="grey",linestyle='--',label = "maigreur")
    plt.axhline(y=25 ,color="green",linestyle='--',label = "normale")
    plt.axhline(y=30,color="yellow",linestyle='--',label = "surpoids")
    plt.axhline(y=35 ,color="orange",linestyle='--',label = "obèse modèrée")
    plt.axhline(y=40,color="red",linestyle='--',label = "obèse massive")

    plt.plot(x,y,marker="o")
    plt.legend()
    plt.gcf().set_size_inches(len(dates)+5,9)
    img_title = "graph_evolution_average_IMC"+"_"+str(now.strftime("%d-%m-%Y_%H%M%S"))+".png"
    fig.suptitle(img_title, fontsize=16)
    path = "Graphes/user_"+str(id_user)+"/"+img_title
    fig.savefig(path)
    plt.close()

    return str("IMG:"+ path)

# %%
def VMA(dataframe,debut,fin,id_user):
    #print("VMA CALCULATION")
    debut_date = debut.split(" ")[0]
    debut_hour = debut.split(" ")[1]
    fin_date = fin.split(" ")[0]
    fin_hour = fin.split(" ")[1]
    
    columns = {'id_user': dataframe['iduser'],'Steps': dataframe['steps'], 'Date': dataframe['date'], 'Hour': dataframe['hour']}
    df_steps = pd.DataFrame(columns)
    df_user = df_steps[(df_steps['id_user'] == id_user)]
    
    dataframe_values= df_user.values
    
    list_steps=[]
    cpt = 0 
    steps = 0 
    
    for i in dataframe_values:
        cpt += 1
        steps += i[1]
        #print(i)
        if cpt % 6 == 0:
            list_steps.append(steps)
            #print(steps)
            cpt =  0
            steps = 0

    
    max_steps_on_six_minutes = max(list_steps)
    stepstometer=max_steps_on_six_minutes /2
    vma_formula = stepstometer/100
    result = "Votre VMA maximale est de "+ str(vma_formula)
    return result

# %%
def average(dataframe,col,debut,fin,id_user):
      
    from datetime import datetime as dt
    now = datetime.datetime.now()
    
    debut_date = debut.split(" ")[0]
    debut_hour = debut.split(" ")[1]
    fin_date = fin.split(" ")[0]
    fin_hour = fin.split(" ")[1]

    fmt = '%d-%m-%Y %H:%M'
    tstamp1 = dt.strptime(debut, fmt)
    tstamp2 = dt.strptime(fin, fmt)
    date_difference = tstamp2-tstamp1
    #print(date_difference.days)
       
    if (col == 'calories'):
        
        if(date_difference.days == 0):
            
            heure_difference = int(str(date_difference / 60).split(":")[1])
         
            columns = {'id_user': dataframe['iduser'],'Steps': dataframe['steps'], 'Date': dataframe['date'],'Hour': dataframe['hour']}
            df_calories = pd.DataFrame(columns)
            df_user = df_calories[(df_calories['id_user'] == id_user)]
            just_hour = []
            for i in df_user["Hour"]:
                just_hour.append(i.split(":")[0])
                
            columns_2 = {'id_user': dataframe['iduser'],'Steps': dataframe['steps'],'Date': dataframe['date'],'Hour': dataframe['hour'],"Heure": just_hour}
            df_calories_h = pd.DataFrame(columns_2)
            

            # Sommes des calories par heure pour faire la moyenne
            somme_per_date = df_calories_h.groupby(df_calories_h["Heure"]).sum()
        

            list_calories = []
            for i in somme_per_date.itertuples():
                list_calories.append(ceil(i.Steps*0.0325))

            columns_3 = {'id_user': somme_per_date['id_user'],'Steps': somme_per_date['Steps'], 'CaloriesByHour': list_calories}
            df_average_calories = pd.DataFrame(columns_3)
            
            somme_calorie_totale = df_average_calories["CaloriesByHour"].sum()
           
            average_calories = ceil(somme_calorie_totale/(heure_difference))
            return "En moyenne par heure, vous avez perdu environ "+ str(average_calories) + " calories du "+ debut_date +" à "+debut_hour+ " au "+ fin_date + " à "+ fin_hour
            
        else:
            columns = {'id_user': dataframe['iduser'],'Steps': dataframe['steps'], 'Date': dataframe['date'],'Hour': dataframe['hour']}
            df_calories = pd.DataFrame(columns)
            df_user = df_calories[(df_calories['id_user'] == id_user)]

            # Sommes des calories par jour pour faire la moyenne
            somme_per_date = df_user.groupby(df_user["Date"]).sum()
            df_values = somme_per_date.values
            

            list_calories = []
            for i in somme_per_date.itertuples():
                list_calories.append(ceil(i.Steps*0.0325))

            columns_2 = {'id_user': somme_per_date['id_user'],'Steps': somme_per_date['Steps'], 'CaloriesByDay': list_calories}
            df_average_calories = pd.DataFrame(columns_2)
            
            somme_calorie_totale = df_average_calories["CaloriesByDay"].sum()
            
            average_calories = ceil(somme_calorie_totale/(date_difference.days+1))

            return "En moyenne par jour, vous avez perdu environ "+ str(average_calories) + " calories du "+ debut_date +" à "+debut_hour+ " au "+ fin_date + " à "+ fin_hour

    if (col == "blood_pressure"):
        
        if(date_difference.days == 0):
            
            print("moyenne par heure")
            heure_difference = int(str(date_difference / 60).split(":")[1])
            print(heure_difference)
            columns = {'id_user': dataframe['iduser'],col: dataframe[col], 'Date': dataframe['date'],'Hour': dataframe['hour']}
            df_number = pd.DataFrame(columns)
            df_user = df_number[(df_number['id_user'] == id_user)]
            systolic = []
            diastolic = []
            for i in df_user[col]:
                systolic.append(float(i.split("/")[0]))
                diastolic.append(float(i.split("/")[1]))   
            just_hour = []
            for i in df_user["Hour"]:
                just_hour.append(i.split(":")[0])

            columns_2 = {'id_user': dataframe['iduser'],col: dataframe[col],"Systolic_value":systolic,"Diastolic_value":diastolic, 'Date': dataframe['date'],'Hour': dataframe['hour'],"Heure": just_hour}
            df_blood_pressure = pd.DataFrame(columns_2)
            somme_sys_value_date = df_blood_pressure["Systolic_value"].groupby(df_blood_pressure["Heure"]).sum()
            somme_dias_value_date = df_blood_pressure["Diastolic_value"].groupby(df_blood_pressure["Heure"]).sum()
            
            somme_totale_sys= somme_sys_value_date.sum()
            somme_totale_dias= somme_dias_value_date.sum()
            
            moyenne_sys_hour = somme_totale_sys/(heure_difference)
            moyenne_dias_hour = somme_totale_dias/(heure_difference)
            
            return "La moyenne par heure de pression sanguine systolique sur la période du "+ debut_date +" à "+debut_hour+" jusqu'au "+ fin_date+" à "+fin_hour+" est de: "+ str(round(moyenne_sys_hour,1))+"/"+str(round(moyenne_dias_hour,1))

    
        else:
            columns = {'id_user': dataframe['iduser'],col: dataframe[col], 'Date': dataframe['date'],'Hour': dataframe['hour']}
            df_number = pd.DataFrame(columns)
            df_user = df_number[(df_number['id_user'] == id_user)]
            systolic = []
            diastolic = []
            for i in df_user[col]:
                systolic.append(float(i.split("/")[0]))
                diastolic.append(float(i.split("/")[1]))

            columns_2 = {'id_user': dataframe['iduser'],col: dataframe[col],"Systolic_value":systolic,"Diastolic_value":diastolic, 'Date': dataframe['date'],'Hour': dataframe['hour']}
            df_blood_pressure = pd.DataFrame(columns_2)
            somme_sys_value_date = df_blood_pressure["Systolic_value"].groupby(df_blood_pressure["Date"]).sum()
            somme_dias_value_date = df_blood_pressure["Diastolic_value"].groupby(df_blood_pressure["Date"]).sum()
            
            somme_totale_sys= somme_sys_value_date.sum()
            somme_totale_dias= somme_dias_value_date.sum()
            
            moyenne_sys_day = somme_totale_sys/(date_difference.days+1)
            moyenne_dias_day = somme_totale_dias/(date_difference.days+1)
            
            return "La moyenne par jour de pression sanguine systolique sur la période du "+ debut_date +" à "+debut_hour+" jusqu'au "+ fin_date+" à "+fin_hour+" est de: "+ str(round(moyenne_sys_day,1))+"/"+str(round(moyenne_dias_day,1))

    
    else:    
        if(date_difference.days == 0):

            heure_difference = int(str(date_difference / 60).split(":")[1])
            
            columns = {'id_user': dataframe['iduser'],col: dataframe[col], 'Date': dataframe['date'],'Hour': dataframe['hour']}
            df_average = pd.DataFrame(columns)
            df_user = df_average[(df_average['id_user'] == id_user)]
            just_hour = []
            for i in df_user["Hour"]:
                just_hour.append(i.split(":")[0])
                
            columns_2 = {'id_user': dataframe['iduser'],col: dataframe[col],'Date': dataframe['date'],'Hour': dataframe['hour'],"Heure": just_hour}
            df_mean = pd.DataFrame(columns_2)
            somme = df_mean[col].groupby(df_mean["Heure"]).sum()
            
            somme_totale = somme.sum()
            moyenne = somme_totale/(heure_difference)

            return "La moyenne de "+ col +" sur la période du "+ debut_date +" à "+debut_hour+" jusqu'au "+ fin_date+" à "+fin_hour+" est de: "+ str(round(moyenne,1))
        else:
            
            columns = {'id_user': dataframe['iduser'],col: dataframe[col], 'Date': dataframe['date'],'Hour': dataframe['hour']}
            df_average = pd.DataFrame(columns)
           
            df_user = df_average[(df_average['id_user'] == id_user)]
            #somme de pas par jour
            somme = df_user[col].groupby(df_user["Date"]).sum()
            somme_totale = somme.sum()
            moyenne = somme_totale/(date_difference.days+1)
            

            return "La moyenne par jour de "+ col +" sur la période du "+ debut_date +" à "+debut_hour+" jusqu'au "+ fin_date+" à "+fin_hour+" est de: "+ str(round(moyenne,1))

# %%
def number(dataframe,col,debut,fin,id_user):
    
    debut_date = debut.split(" ")[0]
    debut_hour = debut.split(" ")[1]
    fin_date = fin.split(" ")[0]
    fin_hour = fin.split(" ")[1]

    
    if (col == "calories"):
        
        columns = {'id_user': dataframe['iduser'],'Steps': dataframe['steps'], 'Date': dataframe['date'],'Hour': dataframe['hour']}
        df_nb_calories = pd.DataFrame(columns)
        df_user = df_nb_calories[(df_nb_calories['id_user'] == id_user)]
        df_steps = df_user['Steps']
               
            
        return "Vous avez perdu environ "+ str(ceil(df_steps.sum()*0.0325)) + " calories du "+ debut_date +" à "+debut_hour+ " au "+ fin_date + " à "+ fin_hour
    
    if (col == "temperature"):
        
        columns = {'id_user': dataframe['iduser'],col: dataframe[col], 'Date': dataframe['date'],'Hour': dataframe['hour']}
        df_number = pd.DataFrame(columns)
        df_user = df_number[(df_number['id_user'] == id_user)]
        max_df = df_user[col].max(axis = 0)
        min_df = df_user[col].min(axis = 0)
        return "La valeur maximale de température durant la période "+ debut_date +" à "+debut_hour+ " au "+ fin_date + " à "+ fin_hour + " est de :"+ str(max_df)+". La valeur minimale de température durant la période "+ debut_date +" à "+debut_hour+ " au "+ fin_date + " à "+ fin_hour + " est de :"+ str(min_df)
    
    if (col == "heartbeat"):
        
        columns = {'id_user': dataframe['iduser'],col: dataframe[col], 'Date': dataframe['date'],'Hour': dataframe['hour']}
        df_number = pd.DataFrame(columns)
        df_user = df_number[(df_number['id_user'] == id_user)]
        max_df = df_user[col].max(axis = 0)
        min_df = df_user[col].min(axis = 0)
        return "La valeur maximale de Heartbeat durant la période "+ debut_date +" à "+debut_hour+ " au "+ fin_date + " à "+ fin_hour + " est de :"+ str(max_df)+". La valeur minimale de heartbeat durant la période "+ debut_date +" à "+debut_hour+ " au "+ fin_date + " à "+ fin_hour + " est de :"+ str(min_df)
    
    
    if (col == "blood_pressure"):
        
        columns = {'id_user': dataframe['iduser'],col: dataframe[col], 'Date': dataframe['date'],'Hour': dataframe['hour']}
        df_number = pd.DataFrame(columns)
        df_user = df_number[(df_number['id_user'] == id_user)]
        systolic = []
        diastolic = []
        for i in df_user[col]:
            systolic.append(i.split("/")[0])
            diastolic.append(i.split("/")[1])
            
        columns_2 = {'id_user': dataframe['iduser'],col: dataframe[col],"Systolic_value":systolic,"Diastolic_value":diastolic, 'Date': dataframe['date'],'Hour': dataframe['hour']}
        df_blood_pressure = pd.DataFrame(columns_2)
        max_sys_value = df_blood_pressure["Systolic_value"].max(axis = 0)
        max_dias_value = df_blood_pressure["Diastolic_value"].max(axis = 0)
        min_sys_value = df_blood_pressure["Systolic_value"].min(axis = 0)
        min_dias_value = df_blood_pressure["Diastolic_value"].min(axis = 0)
        
        return "La valeur maximale de pression sanguine systolique durant la période "+ debut_date +" à "+debut_hour+ " au "+ fin_date + " à "+ fin_hour + " est de :"+ str(max_sys_value+"/"+max_dias_value)+".  La valeur minimale de pression sanguine durant la période "+ debut_date +" à "+debut_hour+ " au "+ fin_date + " à "+ fin_hour + " est de :"+ str(min_sys_value+"/"+min_dias_value)
    
    else:  
            
        columns = {'id_user': dataframe['iduser'],col: dataframe[col], 'Date': dataframe['date'],'Hour': dataframe['hour']}
        df_number = pd.DataFrame(columns)
        df_user = df_number[(df_number['id_user'] == id_user)]
        #max_df = df_user[col].max(axis = 0)
        #min_df = df_user[col].min(axis = 0)
        somme = df_user[col].sum()
        
        
        return "La somme de "+ col +" sur la période du "+debut_date +" à "+debut_hour+" jusqu'au "+ fin_date+" à "+fin_hour+" est de: "+ str(round(somme,1))

# %%
def evolution_average(dataframe,col,debut,fin,id_user):
    
    from datetime import datetime as dt
    now = datetime.datetime.now()

    fmt = '%d-%m-%Y %H:%M'
    tstamp1 = dt.strptime(debut, fmt)
    tstamp2 = dt.strptime(fin, fmt)
    date_difference = tstamp2-tstamp1
    #print(date_difference.days)
    
    if (col == "calories"):
        
        """
        if(date_difference.days == 0):
            print("moyenne par heure")
            heure_difference = int(str(date_difference / 60).split(":")[1])
            print(heure_difference)
            columns = {'id_user': dataframe['iduser'],'Steps': dataframe['steps'], 'Date': dataframe['date'],'Hour': dataframe['hour']}
            df_calories = pd.DataFrame(columns)
            df_user = df_calories[(df_calories['id_user'] == id_user)]
            just_hour = []
            for i in df_user["Hour"]:
                just_hour.append(i.split(":")[0])
                
            columns_2 = {'id_user': dataframe['iduser'],'Steps': dataframe['steps'],'Date': dataframe['date'],'Hour': dataframe['hour'],"Heure": just_hour}
            df_calories_h = pd.DataFrame(columns_2)
            #display(df_calories_h)

            # Sommes des calories par heure pour faire la moyenne
            somme_per_date = df_calories_h.groupby(df_calories_h["Heure"]).sum()
            display(somme_per_date)

            list_calories = []
            for i in somme_per_date.itertuples():
                list_calories.append(ceil(i.Steps*0.0325))

            columns_3 = {'id_user': somme_per_date['id_user'],'Steps': somme_per_date['Steps'], 'CaloriesByHour': list_calories}
            df_average_calories = pd.DataFrame(columns_3)
            display(df_average_calories)
            somme_calorie_totale = df_average_calories["CaloriesByHour"].sum()
            display(somme_calorie_totale)
            average_calories = ceil(somme_calorie_totale/(heure_difference))"""
        
        
        if(date_difference.days >8):
            
            columns = {'id_user': dataframe['iduser'],'Steps': dataframe['steps'], 'Date': dataframe['date'],'Hour': dataframe['hour']}
            df_nb_calories = pd.DataFrame(columns)
            df_user = df_nb_calories[(df_nb_calories['id_user'] == id_user)]
            #display(df_user)
            dayoftheweek = []
            for i in df_user["Date"]:
                temp = pd.Timestamp(i)
                dayoftheweek.append(temp.day_name())
                
            columns_2 = {'id_user': df_user['id_user'],'Steps': dataframe['steps'], 'Date': dataframe['date'],'Hour': dataframe['hour'],"DayoftheWeek":dayoftheweek}
            df_calories_by_day = pd.DataFrame(columns_2)
            display(df_calories_by_day)
            
            df_cal_by_day1 = df_calories_by_day.groupby(df_calories_by_day["DayoftheWeek"]).sum()# Sommes des steps par jour de la semaine
            df_cal_by_day = df_cal_by_day1.sort_index()
            only_for_index = df_calories_by_day.groupby(df_calories_by_day["Date"]).sum()
            display(df_cal_by_day)
            
            #diviser par le nombre de jour par semaine
            dates = only_for_index.index
            print(dates)
            Monday = 0
            Tuesday = 0
            Wednesday = 0
            Thursday = 0
            Friday = 0
            Saturday = 0
            Sunday = 0
            
            for i in dates:
                temp = pd.Timestamp(i)
                if (temp.day_name() == 'Monday'):
                    Monday += 1
                if (temp.day_name() == 'Tuesday'):
                    Tuesday += 1
                if (temp.day_name() == 'Wednesday'):
                    Wednesday += 1
                if (temp.day_name() == 'Thursday'):
                    Thursday += 1
                if (temp.day_name() == 'Friday'):
                    Friday += 1
                if (temp.day_name() == 'Saturday'):
                    Saturday += 1
                if (temp.day_name() == 'Sunday'):
                    Sunday += 1
            print(Monday,Tuesday,Wednesday,Thursday,Friday,Saturday,Sunday)
                
            display(df_cal_by_day)
            list_mean_calories = []
            for i in df_cal_by_day.itertuples():
                
                somme_calories = ceil(i.Steps*0.0325)
                print("la somme de calories est de ",somme_calories)
                if (i.Index == 'Monday'):
                    print(i.Index)
                    moyenne = somme_calories / Monday
                    list_mean_calories.append(ceil(moyenne))
                if (i.Index =='Tuesday'):
                    print(i.Index)
                    moyenne = somme_calories / Tuesday
                    list_mean_calories.append(ceil(moyenne))
                if (i.Index == 'Wednesday'):
                    print(i.Index)
                    moyenne = somme_calories / Wednesday
                    list_mean_calories.append(ceil(moyenne))
                if (i.Index == 'Thursday'):
                    print(i.Index)
                    moyenne = somme_calories / Thursday
                    list_mean_calories.append(ceil(moyenne))
                if (i.Index == 'Friday'):
                    print(i.Index)
                    moyenne = somme_calories / Friday
                    list_mean_calories.append(ceil(moyenne))
                if (i.Index == 'Saturday'):
                    print(i.Index)
                    moyenne = somme_calories / Saturday
                    list_mean_calories.append(ceil(moyenne))
                if (i.Index == 'Sunday'):
                    print(i.Index)
                    moyenne = somme_calories / Sunday
                    list_mean_calories.append(ceil(moyenne))
            
            # Moyenne des calories par heure pour faire la moyenne
            

            columns_mean_values = pd.to_numeric(list_mean_calories)
            day_of_week = (df_cal_by_day.index)

            fig = plt.figure()
            x=np.array(day_of_week)
            y=np.array(columns_mean_values)

            plt.plot(x,y,marker="o",label = "Moyenne_Calories_par_jour")
            plt.legend()
            plt.gcf().set_size_inches(len(day_of_week)+5,9)
            img_title = "graph_evolution_average"+str(col)+"_"+str(now.strftime("%d-%m-%Y_%H%M%S"))+".png"
            fig.suptitle(img_title, fontsize=16)
            path = "Graphes/user_"+str(id_user)+"/"+img_title
            fig.savefig(path)
            #plt.close()"""
            #return "moyenne by day"
            return str("IMG:"+ path)
            
        else:
        
            columns = {'id_user': dataframe['iduser'],'Steps': dataframe['steps'], 'Date': dataframe['date'],'Hour': dataframe['hour']}
            df_nb_calories = pd.DataFrame(columns)
            df_user = df_nb_calories[(df_nb_calories['id_user'] == id_user)]

            # Sommes des calories par jour pour faire la moyenne
            df_cal_bydate = df_user.groupby(df_user["Date"]).sum()       

            list_calories = []
            for i in df_cal_bydate.itertuples():
                list_calories.append(ceil(i.Steps*0.0325))

            list_mean_calories=[]
            for j in list_calories:
                list_mean_calories.append(j/24)

            columns_2 = {'id_user': df_cal_bydate['id_user'],'MeanCaloriesByDay': list_mean_calories}
            df_average_calories = pd.DataFrame(columns_2)
            display(df_average_calories)

            columns_values_by_dates = pd.to_numeric(df_average_calories["MeanCaloriesByDay"].values)
            dates = pd.to_datetime(df_average_calories.index)

            fig = plt.figure()
            x=[date.strftime("%m-%d-%Y") for date in dates]
            y=np.array(columns_values_by_dates)

            
            plt.plot(x,y,marker="o",label = "Moyenne_Calories_par_jour")
            plt.legend()
            plt.gcf().set_size_inches(len(dates)+5,9)
            img_title = "graph_evolution_average"+str(col)+"_"+str(now.strftime("%d-%m-%Y_%H%M%S"))+".png"
            fig.suptitle(img_title, fontsize=16)
            path = "Graphes/user_"+str(id_user)+"/"+img_title
            fig.savefig(path)
            #plt.close()

            return str("IMG:"+ path)
            
    
    if (col == "blood_pressure"):
        
        if(date_difference.days == 0):
            
            columns = {'id_user': dataframe['iduser'],col: dataframe[col], 'Date': dataframe['date'],'Hour': dataframe['hour']}
            df_number = pd.DataFrame(columns)
            df_user = df_number[(df_number['id_user'] == id_user)]
            systolic = []
            diastolic = []
            for i in df_user[col]:
                systolic.append(float(i.split("/")[0]))
                diastolic.append(float(i.split("/")[1]))
            just_hour = []
            for i in df_user["Hour"]:
                just_hour.append(i.split(":")[0])

            columns_2 = {'id_user': dataframe['iduser'],col: dataframe[col],"Systolic_value":systolic,"Diastolic_value":diastolic, 'Date': dataframe['date'],'Hour': dataframe['hour'],'Heure': just_hour}
            df_blood_pressure = pd.DataFrame(columns_2)
            df_mean = df_blood_pressure.groupby(df_blood_pressure["Heure"]).mean()
            sys = df_mean["Systolic_value"].values
            dias = df_mean["Diastolic_value"].values
            hours = pd.to_numeric(df_mean.index)

            fig = plt.figure()
            x_mean_sys=np.array(hours)
            y_mean_sys=np.array(sys)
            x_mean_dias=np.array(hours)
            y_mean_dias=np.array(dias)

            plt.plot(x_mean_sys, y_mean_sys, label = "moyenne PS systolique par heure")
            plt.plot(x_mean_dias, y_mean_dias, label = "moyenne PS diastolique par heure")
            plt.legend()
            plt.gcf().set_size_inches(len(hours)+5,9)
            img_title = "graph_evolution_average"+str(col)+"_"+str(now.strftime("%d-%m-%Y_%H%M%S"))+".png"
            fig.suptitle(img_title, fontsize=16)
            path = "Graphes/user_"+str(id_user)+"/"+img_title
            fig.savefig(path)
            #plt.close()
            return str("IMG:"+ path)
            
        else:
            columns = {'id_user': dataframe['iduser'],col: dataframe[col], 'Date': dataframe['date'],'Hour': dataframe['hour']}
            df_number = pd.DataFrame(columns)
            df_user = df_number[(df_number['id_user'] == id_user)]
            systolic = []
            diastolic = []
            for i in df_user[col]:
                systolic.append(float(i.split("/")[0]))
                diastolic.append(float(i.split("/")[1]))

            columns_2 = {'id_user': dataframe['iduser'],col: dataframe[col],"Systolic_value":systolic,"Diastolic_value":diastolic, 'Date': dataframe['date'],'Hour': dataframe['hour']}
            df_blood_pressure = pd.DataFrame(columns_2)
            df_mean = df_blood_pressure.groupby(df_blood_pressure["Date"]).mean()
            sys = df_mean["Systolic_value"].values
            dias = df_mean["Diastolic_value"].values
            dates = pd.to_datetime(df_mean.index)

            fig = plt.figure()
            x_mean_sys=[date.strftime("%m-%d-%Y") for date in dates]
            y_mean_sys=np.array(sys)
            x_mean_dias=[date.strftime("%m-%d-%Y") for date in dates]
            y_mean_dias=np.array(dias)

            plt.plot(x_mean_sys, y_mean_sys, label = "moyenne PS systolique")
            plt.plot(x_mean_dias, y_mean_dias, label = "moyenne PS diastolique")
            plt.legend()
            plt.gcf().set_size_inches(len(dates)+1,9)
            img_title = "graph_evolution_average"+str(col)+"_"+str(now.strftime("%d-%m-%Y_%H%M%S"))+".png"
            fig.suptitle(img_title, fontsize=16)
            path = "Graphes/user_"+str(id_user)+"/"+img_title
            fig.savefig(path)
            #plt.close()
            return str("IMG:"+ path)
      
    else:
        
        if(date_difference.days == 0):
            
            columns = {'id_user': dataframe['iduser'],col: dataframe[col], 'Date': dataframe['date'],'Hour': dataframe['hour']}
            df_number = pd.DataFrame(columns)
            df_user = df_number[(df_number['id_user'] == id_user)]
            just_hour = []
            for i in df_user["Hour"]:
                just_hour.append(i.split(":")[0])
                
            columns_2 = {'id_user': dataframe['iduser'],col: dataframe[col],'Date': dataframe['date'],'Hour': dataframe['hour'],"Heure": just_hour}
            df_mean = pd.DataFrame(columns_2)
            
            df_group = df_mean.groupby(df_mean["Heure"]).mean()
            df_group.sort_index(ascending=False)
            columns_values_by_hours = pd.to_numeric(df_group[col].values)
            hours = pd.to_numeric(df_group.index)

            fig = plt.figure()
            x=np.array(hours)
            y=np.array(columns_values_by_hours)

            plt.plot(x,y,marker="o",label = "Moyenne_"+str(col)+"_par_heure")
            plt.legend()
            plt.gcf().set_size_inches(len(hours)+5,9)
            img_title = "graph_evolution_average_"+str(col)+"_"+str(now.strftime("%d-%m-%Y_%H%M%S"))+".png"
            fig.suptitle(img_title, fontsize=16)
            path = "Graphes/user_"+str(id_user)+"/"+img_title
            fig.savefig(path)
            #plt.close()
            return str("IMG:"+ path)
        else:
            columns = {'id_user': dataframe['iduser'],col: dataframe[col], 'Date': dataframe['date'],'Hour': dataframe['hour']}
            df_number = pd.DataFrame(columns)
            df_user = df_number[(df_number['id_user'] == id_user)]
            df_group = df_user.groupby(df_user["Date"]).mean()
            df_group.sort_index(ascending=False)
            columns_values_by_dates = pd.to_numeric(df_group[col].values)
            dates = pd.to_datetime(df_group.index)

            fig = plt.figure()
            x=[date.strftime("%m-%d-%Y") for date in dates]
            y=np.array(columns_values_by_dates)

            plt.plot(x,y,marker="o",label = "Moyenne_"+str(col)+"_par_jour")
            plt.legend()
            plt.gcf().set_size_inches(len(dates)+5,9)
            img_title = "graph_evolution_average_"+str(col)+"_"+str(now.strftime("%d-%m-%Y_%H%M%S"))+".png"
            fig.suptitle(img_title, fontsize=16)
            path = "Graphes/user_"+str(id_user)+"/"+img_title
            fig.savefig(path)
            #plt.close()
            return str("IMG:"+ path)

# %%
def evolution_number(dataframe,col,debut,fin,id_user):
    now = datetime.datetime.now()
     
    if (col == "calories"):
        
        columns = {'id_user': dataframe['iduser'],'Steps': dataframe['steps'], 'Date': dataframe['date'],'Hour': dataframe['hour']}
        df_nb_calories = pd.DataFrame(columns)
        df_user = df_nb_calories[(df_nb_calories['id_user'] == id_user)]
        
        # Sommes des calories par jour pour faire la moyenne
        df_cal_bydate = df_user.groupby(df_user["Date"]).sum()
        df_values = df_cal_bydate.values
        
        list_calories = []
        for i in df_values:
            list_calories.append(ceil(i[1]*0.0325))
            
        columns_2 = {'id_user': df_cal_bydate['id_user'],'CaloriesByDay': list_calories}
        df_average_calories = pd.DataFrame(columns_2)
        
        columns_values_by_dates = pd.to_numeric(df_average_calories["CaloriesByDay"].values)
        dates =df_average_calories.index
        
        fig = plt.figure()
        x=np.array(dates)
        y=np.array(columns_values_by_dates)

        plt.plot(x,y,marker="o",label = "Nombre de Calories_par_jour")
        plt.legend()
        plt.gcf().set_size_inches(len(dates)+5,9)
        img_title = "graph_evolution_number"+str(col)+"_"+str(now.strftime("%d-%m-%Y_%H%M%S"))+".png"
        fig.suptitle(img_title, fontsize=16)
        path = "Graphes/user_"+str(id_user)+"/"+img_title
        fig.savefig(path)
        plt.close()
        
        return str("IMG:"+ path)
    
    if (col == "temperature"):
        
        columns = {'id_user': dataframe['iduser'],col: dataframe[col], 'Date': dataframe['date'],'Hour': dataframe['hour']}
        df_number = pd.DataFrame(columns)
        df_user = df_number[(df_number['id_user'] == id_user)]
        df_min_max_agg = df_user.groupby(df_user["Date"]).agg(['min', 'max'])
        df_temp = df_min_max_agg["temperature"]
        min_values_per_day = df_temp["min"].values
        max_values_per_day = df_temp["max"].values
        dates = df_temp.index
        
        fig = plt.figure()
        x_max=np.array(dates)
        y_max=np.array(max_values_per_day)
        x_min=np.array(dates)
        y_min=np.array(min_values_per_day)
        
        plt.plot(x_max, y_max, label = "C° maximales par jour ")
        plt.plot(x_min, y_min, label = "C° minimales par jour ")
        plt.legend()
        plt.gcf().set_size_inches(len(dates)+5,9)
        img_title = "graph_evolution_number"+str(col)+"_"+str(now.strftime("%d-%m-%Y_%H%M%S"))+".png"
        fig.suptitle(img_title, fontsize=16)
        path = "Graphes/user_"+str(id_user)+"/"+img_title
        fig.savefig(path)
        plt.close()
        
        return str("IMG:"+ path)
    
    if (col == "blood_pressure"):
        
        columns = {'id_user': dataframe['iduser'],col: dataframe[col], 'Date': dataframe['date'],'Hour': dataframe['hour']}
        df_number = pd.DataFrame(columns)
        df_user = df_number[(df_number['id_user'] == id_user)]
        systolic = []
        diastolic = []
        for i in df_user[col]:
            systolic.append(i.split("/")[0])
            diastolic.append(i.split("/")[1])
            
        columns_2 = {'id_user': dataframe['iduser'],col: dataframe[col],"Systolic_value":systolic,"Diastolic_value":diastolic, 'Date': dataframe['date'],'Hour': dataframe['hour']}
        df_blood_pressure = pd.DataFrame(columns_2)
        df_min_max_agg = df_blood_pressure.groupby(df_blood_pressure["Date"]).agg(['min', 'max'])
        sys = df_min_max_agg["Systolic_value"]
        dias = df_min_max_agg["Diastolic_value"]
        max_sys_values = pd.to_numeric(sys["max"].values)
        max_dias_values = pd.to_numeric(dias["max"].values)
        min_sys_values =pd.to_numeric(sys["min"].values)
        min_dias_values = pd.to_numeric(dias["min"].values)
        dates = df_min_max_agg.index
        
        fig = plt.figure()
        x_max_min_sys_dias=np.array(dates)
        y_max_sys=np.array(max_sys_values)
        y_min_sys=np.array(min_sys_values)
        y_max_dias=np.array(max_dias_values)
        y_min_dias=np.array(min_dias_values)
        
        plt.plot(x_max_min_sys_dias, y_max_dias, label = "max PS diastolique  par jour")
        plt.plot(x_max_min_sys_dias, y_min_dias, label = "min PS diastolique  par jour")
        plt.plot(x_max_min_sys_dias, y_min_sys, label = "min PS systolique  par jour")  
        plt.plot(x_max_min_sys_dias, y_max_sys, label = "max PS systolique par jour")
        
        plt.legend()
        plt.gcf().set_size_inches(len(dates)+5,9)
        img_title = "graph_evolution_number"+str(col)+"_"+str(now.strftime("%d-%m-%Y_%H%M%S"))+".png"
        fig.suptitle(img_title, fontsize=16)
        path = "Graphes/user_"+str(id_user)+"/"+img_title
        fig.savefig(path)
        plt.close()
        return str("IMG:"+ path)
    
    if (col == "heartbeat"):
        
        columns = {'id_user': dataframe['iduser'],col: dataframe[col], 'Date': dataframe['date'],'Hour': dataframe['hour']}
        df_number = pd.DataFrame(columns)
        df_user = df_number[(df_number['id_user'] == id_user)]
        df_min_max_agg = df_user.groupby(df_user["Date"]).agg(['min', 'max'])
        df_temp = df_min_max_agg[col]
        min_values_per_day = pd.to_numeric(df_temp["min"].values)
        max_values_per_day = pd.to_numeric(df_temp["max"].values)
        dates = df_temp.index
        fig = plt.figure()
        x_max=np.array(dates)
        y_max=np.array(max_values_per_day)
        x_min=np.array(dates)
        y_min=np.array(min_values_per_day)
        
        plt.plot(x_max, y_max, label = "valeurs maximales par jour ")
        plt.plot(x_min, y_min, label = "valeurs minimales par jour ")
        plt.legend()
        plt.gcf().set_size_inches(len(dates)+5,9)
        img_title = "graph_evolution_number"+str(col)+"_"+str(now.strftime("%d-%m-%Y_%H%M%S"))+".png"
        fig.suptitle(img_title, fontsize=16)
        path = "Graphes/user_"+str(id_user)+"/"+img_title
        fig.savefig(path)
        plt.close()
        
        return str("IMG:"+ path)
        
    else:
        
        columns = {'id_user': dataframe['iduser'],col: dataframe[col], 'Date': dataframe['date'],'Hour': dataframe['hour']}
        df_number = pd.DataFrame(columns)
        df_user = df_number[(df_number['id_user'] == id_user)]
        df_group = df_user.groupby(df_user["Date"]).sum()
        df_group.sort_index(ascending=False)
        columns_values_by_dates = pd.to_numeric(df_group[col].values)
        dates = df_group.index
    
        fig = plt.figure()
        x=np.array(dates)
        y=np.array(columns_values_by_dates)

        plt.plot(x,y,marker="o",label = "Nombre de "+str(col)+"_par_jour")
        plt.legend()
        plt.gcf().set_size_inches(len(dates)+5,9)
        img_title = "graph_evolution_number "+str(col)+"_"+str(now.strftime("%d-%m-%Y_%H%M%S"))+".png"
        fig.suptitle(img_title, fontsize=16)
        path = "Graphes/user_"+str(id_user)+"/"+img_title
        fig.savefig(path)
        plt.close()
    
        return str("IMG:"+ path)

# %%
def actions(analyse,colonnes,debut,fin,id_user):
    
    s3 = boto3.client('s3', aws_access_key_id='AKIAXENTS6UZG2MIL4GG',aws_secret_access_key='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', region_name='eu-west-3')
    d1 = debut.split(" ")[0]
    d2 = fin.split(" ")[0]
    h1 = debut.split(" ")[1]
    h2 = fin.split(" ")[1]
    
    #day,month,year d1
    day1 = int(d1.split("-")[0])
    month1 = int(d1.split("-")[1])
    year1 = int(d1.split("-")[2])

    #day,month,year d2
    day2 = int(d2.split("-")[0])
    month2 = int(d2.split("-")[1])
    year2 = int(d2.split("-")[2])

    sdate = date(year1, month1, day1)   # start date
    edate = date(year2, month2, day2)   # end date

    delta = edate - sdate       # as timedelta
    #print(delta)
    list_dates = []
    # Récuperation des dates de la periode donnée en paramètre
    for i in range(delta.days + 1):
        day = sdate + timedelta(days=i)
        list_dates.append(str(day.strftime("%d-%m-%Y")))

    liste = []

    # Récuperation des données datant de la periode sélectionné
    for i in list_dates:
        s3_file_key = str(id_user)+'/health/'+i+'/health_data.csv'
        bucket = 's3fakewatch'
        #print(s3_file_key)
        obj = s3.get_object(Bucket=bucket, Key=s3_file_key)
        initial_df = pd.read_csv(io.BytesIO(obj['Body'].read()))
        liste.append(initial_df)

    frame = pd.concat(liste, axis=0, ignore_index=True)
    frame.to_csv (r'health_data_finale.csv', index = False, header=True)
    
    # Récuperation des données datant de l'heure périodique sélectionné
    first_position = 0
    for i in frame.itertuples():
        if (i.date == d1 and i.hour == h1):
            #print(i,first_position)
            break;
        first_position = first_position + 1
        
    last_position = 0
    for i in frame.itertuples():
        if (i.date == d2 and i.hour == h2):
            #print(i,last_position)
            break;
        last_position = last_position + 1 
    
    final_dataframe = frame.loc[first_position:last_position]
    #display(final_dataframe)
    
    if not os.path.exists("Traitement_Data/Graphes/user_"+str(id_user)+"/"):
        os.mkdir("Traitement_Data/")
        os.mkdir("Traitement_Data/Graphes/")
        os.mkdir("Traitement_Data/Graphes/user_"+str(id_user)+"/")        
    else:
        pass
        
    if analyse =='average':
        if colonnes in ['heartbeat','calories','steps','temperature','blood_pressure'] :
            return average(final_dataframe,colonnes,debut,fin,id_user)
        else: 
            return "Colonnes de données non existantes"
    if analyse =='number':
        if colonnes in ['heartbeat','calories','steps','temperature','blood_pressure']  :
            return number(final_dataframe,colonnes,debut,fin,id_user)
        else: 
            return "Colonnes de données non existantes"
    if analyse =='evolution_average':
        if colonnes in ['heartbeat','calories','steps','temperature','blood_pressure'] :
            return evolution_average(final_dataframe,colonnes,debut,fin,id_user)
        if (colonnes == 'IMC'):
            return evolution_average_IMC(final_dataframe,id_user)
        else: 
            return "Colonnes de données non existantes"
    if analyse =='evolution_number':
        if colonnes in ['heartbeat','calories','steps','temperature','blood_pressure'] :
            return evolution_number(final_dataframe,colonnes,debut,fin,id_user)
        if (colonnes == 'IMC'):
            return evolution_number_IMC(final_dataframe,id_user)
        else: 
            return "Colonnes de données non existantes"
    if analyse =='':
        if colonnes == "VMA":
            #print("VMA CALCULATION")
            return VMA(final_dataframe,debut,fin,id_user)
        if colonnes == "IMC":
            #print("IMC CALCULATION")
            return IMC(final_dataframe,id_user)

# %%
r = actions("average",'blood_pressure','04-05-2021 00:00','15-05-2021 16:00',2)
r
# Out:
# "La moyenne par jour de pression sanguine systolique sur la période du 04-05-2021 à 00:00 jusqu'au 15-05-2021 à 16:00 est de: 156955.5/98395.1"

# %%
os.remove("health_data_finale.csv")
